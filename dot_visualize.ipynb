# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from pyspark.sql.functions import concat, to_timestamp, col, lit

# %%
# Import necessary libraries
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import sum as spark_sum, col, hour, concat_ws, to_date, date_format
# Stop any existing Spark session
# Step 1: Initialize a Spark session
spark = SparkSession.builder \
    .appName("BigDataProcessing") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()
# Step 2: Load your CSV file into a Spark DataFrame
data = spark.read.csv("June2024.csv", header=True, inferSchema=True)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/11/07 18:54:47 WARN Utils: Your hostname, J4Hp resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/11/07 18:54:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/07 18:54:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql.functions import to_timestamp, concat, col, lit, date_format, expr
# Filter rows where ROUTE_ID is 'acwXkRFM'
# data = data.filter(col("ROUTE_ID") == 'acwXkRFM')
# Step 2: Format TICKET_ISSUE_TIME as a string in "HH:mm:ss" format (if not already) and combine date and time
data = data.withColumn("TICKET_ISSUE_TIME_STR", date_format(col("TICKET_ISSUE_TIME"), "HH:mm:ss"))
data = data.withColumn("TICKET_DATETIME_STR", concat(col("TICKET_ISSUE_DATE"), lit(" "), col("TICKET_ISSUE_TIME_STR")))

# Step 3: Convert the combined date-time string to a timestamp format
data = data.withColumn("TICKET_DATETIME", to_timestamp("TICKET_DATETIME_STR", "dd/MM/yyyy HH:mm:ss"))

# Step 4: Round TICKET_DATETIME to the nearest 10-minute interval
data = data.withColumn("TICKET_DATETIME_10MIN", expr("date_trunc('minute', TICKET_DATETIME) + INTERVAL 10 MINUTE * floor(minute(TICKET_DATETIME) / 10)"))

# %%
# print("Schema after adding TICKET_DATETIME:")
# data.printSchema()
data.show(5)
# Out:
# +--------------------+-----------------+-------------------+--------------+---------------+------------+----------+--------+-----------+------------+---------+-----------------+--------------------+-----------+-----------+----------+------+---------------+---------------+-------+------------+---------------------+-------------------+-------------------+---------------------+
# |          DEPOT_NAME|TICKET_ISSUE_DATE|  TICKET_ISSUE_TIME|WAYBILL_NUMBER|SCHEDULE_NUMBER|SERVICE_TYPE|ROUTE_NAME|ROUTE_ID|TRIP_NUMBER|          ID|TICKET_NO|   FROM_STOP_NAME|        TO_STOP_NAME|NO_OF_ADULT|NO_OF_CHILD|NO_OF_LUGG|OTHERS|TOTAL_PASSENGER|DISTANCE_TRAVEL|TRIP_KM|PAYMENT_TYPE|TICKET_ISSUE_TIME_STR|TICKET_DATETIME_STR|    TICKET_DATETIME|TICKET_DATETIME_10MIN|
# +--------------------+-----------------+-------------------+--------------+---------------+------------+----------+--------+-----------+------------+---------+-----------------+--------------------+-----------+-----------+----------+------+---------------+---------------+-------+------------+---------------------+-------------------+-------------------+---------------------+
# |TRIVANDRUM CITY D...|       31/05/2024|2024-11-07 09:03:06|      14146419|  1C 3 Duty 605|    Ordinary|     1614D|cIPyJWNe|          5|100876443615|      191|         Vembayam| East Fort Bus Stand|          2|          0|         0|     0|              2|          19.18|   12.5|        Cash|             09:03:06|31/05/2024 09:03:06|2024-05-31 09:03:06|  2024-05-31 09:03:00|
# |    PEROORKADA Depot|       31/05/2024|2024-11-07 09:01:59|      14138653|  3C-1-Duty 401|    Ordinary|3C Magenta|pXrJZCnm|          6|100876440259|      258|          Kowdiar|Thampanoor Main B...|          1|          0|         0|     0|              1|            4.9|   19.5|        Cash|             09:01:59|31/05/2024 09:01:59|2024-05-31 09:01:59|  2024-05-31 09:01:00|
# |TRIVANDRUM CITY D...|       31/05/2024|2024-11-07 09:02:31|      14146419|  1C 3 Duty 605|    Ordinary|     1614D|cIPyJWNe|          5|100876441886|      190|         Vembayam|         Mannanthala|          1|          0|         0|     0|              1|           9.73|   12.5|        Cash|             09:02:31|31/05/2024 09:02:31|2024-05-31 09:02:31|  2024-05-31 09:02:00|
# |    PEROORKADA Depot|       31/05/2024|2024-11-07 09:01:09|      14138723|  3A-1 Duty 405|    Ordinary|3A Magenta|NhhoJAsr|          6|100876437738|      228|Pattom Sut Office|Thampanoor Railwa...|          1|          0|         0|     0|              1|           3.86|   17.0|        Cash|             09:01:09|31/05/2024 09:01:09|2024-05-31 09:01:09|  2024-05-31 09:01:00|
# |    PEROORKADA Depot|       31/05/2024|2024-11-07 09:00:39|      14138653|  3C-1-Duty 401|    Ordinary|3C Magenta|pXrJZCnm|          6|100876436214|      255|          Kowdiar|Thampanoor Main B...|          2|          0|         0|     0|              2|            4.9|   19.5|        Cash|             09:00:39|31/05/2024 09:00:39|2024-05-31 09:00:39|  2024-05-31 09:00:00|
# +--------------------+-----------------+-------------------+--------------+---------------+------------+----------+--------+-----------+------------+---------+-----------------+--------------------+-----------+-----------+----------+------+---------------+---------------+-------+------------+---------------------+-------------------+-------------------+---------------------+
# only showing top 5 rows

# %%
# # Group by TICKET_DATETIME, FROM_STOP_NAME, and TO_STOP_NAME, and sum the TOTAL_PASSENGER
aggregated_data_from = (
    data.groupBy("TICKET_DATETIME_10MIN", "FROM_STOP_NAME")
    .sum("TOTAL_PASSENGER")
    .withColumnRenamed("sum(TOTAL_PASSENGER)", "TOTAL_PASSENGER")
)
# Sort by TICKET_DATETIME_5MIN
aggregated_data_from = aggregated_data_from.orderBy("TICKET_DATETIME_10MIN")
aggregated_data_from.show(500)
# Out:
# [Stage 5:>                                                          (0 + 8) / 8]
# +---------------------+--------------------+---------------+
# |TICKET_DATETIME_10MIN|      FROM_STOP_NAME|TOTAL_PASSENGER|
# +---------------------+--------------------+---------------+
# |  2024-05-31 01:45:00|    Peroorkada Depot|              1|
# |  2024-05-31 01:46:00|    Peroorkada Depot|              9|
# |  2024-05-31 01:47:00|    Peroorkada Depot|              1|
# |  2024-05-31 01:47:00|         Ambalamukku|              5|
# |  2024-05-31 01:48:00|         Ambalamukku|              7|
# |  2024-05-31 01:49:00|         Ambalamukku|              1|
# |  2024-05-31 02:00:00|   Pattom Sut Office|              1|
# |  2024-05-31 02:00:00|         Kumarapuram|              2|
# |  2024-05-31 02:00:00|         Ambalamukku|              3|
# |  2024-05-31 02:00:00|             Kowdiar|              3|
# |  2024-05-31 02:01:00|   Pattom Sut Office|              3|
# |  2024-05-31 02:01:00|         Ambalamukku|              3|
# |  2024-05-31 02:01:00|East Fort South B...|              3|
# |  2024-05-31 02:01:00|    Peroorkada Depot|              3|
# |  2024-05-31 02:01:00|         Kumarapuram|              3|
# |  2024-05-31 02:02:00|       Vellayambalam|              1|
# |  2024-05-31 02:02:00|    Peroorkada Depot|              6|
# |  2024-05-31 02:03:00|East Fort South B...|              4|
# |  2024-05-31 02:03:00|    Peroorkada Depot|              2|
# |  2024-05-31 02:03:00|   Pattom Sut Office|              1|
# |  2024-05-31 02:04:00|East Fort South B...|              5|
# |  2024-05-31 02:04:00|        Murinjapalam|              4|
# |  2024-05-31 02:04:00|     Kesavadasapuram|              1|
# |  2024-05-31 02:05:00|East Fort South B...|              4|
# |  2024-05-31 02:05:00|             Kowdiar|              2|
# |  2024-05-31 02:05:00|    Peroorkada Depot|              4|
# |  2024-05-31 02:05:00|        Murinjapalam|              3|
# |  2024-05-31 02:06:00|    Peroorkada Depot|              6|
# |  2024-05-31 02:06:00|        Murinjapalam|              4|
# |  2024-05-31 02:06:00|Palayam Fine Arts...|              7|
# |  2024-05-31 02:06:00|East Fort South B...|              6|
# |  2024-05-31 02:06:00|   Pattom Sut Office|              1|
# |  2024-05-31 02:07:00|        Murinjapalam|              3|
# |  2024-05-31 02:07:00|Palayam Fine Arts...|              4|
# |  2024-05-31 02:07:00|East Fort South B...|              5|
# |  2024-05-31 02:07:00|         Kumarapuram|              6|
# |  2024-05-31 02:08:00|         Kumarapuram|              9|
# |  2024-05-31 02:08:00|        Murinjapalam|              4|
# |  2024-05-31 02:08:00|Palayam Fine Arts...|              1|
# |  2024-05-31 02:09:00|East Fort South B...|              3|
# |  2024-05-31 02:09:00|Lms Corporation O...|              3|
# |  2024-05-31 02:09:00|Palayam Fine Arts...|              1|
# |  2024-05-31 02:09:00|         Kumarapuram|              4|
# |  2024-05-31 02:20:00|East Fort South B...|              2|
# |  2024-05-31 02:20:00|         Kumarapuram|              4|
# |  2024-05-31 02:20:00|Medical College T...|              5|
# |  2024-05-31 02:20:00|    Peroorkada Depot|              4|
# |  2024-05-31 02:21:00|East Fort South B...|              3|
# |  2024-05-31 02:21:00|             Kowdiar|              2|
# |  2024-05-31 02:21:00|         Kumarapuram|              2|
# |  2024-05-31 02:21:00|    Peroorkada Depot|              1|
# |  2024-05-31 02:21:00|Medical College T...|              1|
# |  2024-05-31 02:21:00|           Mettukada|              3|
# |  2024-05-31 02:22:00|         Kumarapuram|              2|
# |  2024-05-31 02:22:00|East Fort South B...|              3|
# |  2024-05-31 02:22:00|East Fort North B...|              3|
# |  2024-05-31 02:22:00|Palayam Fine Arts...|              1|
# |  2024-05-31 02:22:00|        Murinjapalam|              5|
# |  2024-05-31 02:23:00|East Fort North B...|              7|
# |  2024-05-31 02:23:00|        Murinjapalam|              3|
# |  2024-05-31 02:23:00|East Fort South B...|              1|
# |  2024-05-31 02:24:00|East Fort South B...|              4|
# |  2024-05-31 02:24:00|East Fort North B...|              2|
# |  2024-05-31 02:25:00|Thampanoor Main B...|              3|
# |  2024-05-31 02:25:00|   Pattom Sut Office|              1|
# |  2024-05-31 02:25:00|    Peroorkada Depot|              7|
# |  2024-05-31 02:25:00|Medical College T...|              2|
# |  2024-05-31 02:25:00|             Kowdiar|              3|
# |  2024-05-31 02:25:00|East Fort North B...|              8|
# |  2024-05-31 02:25:00|        Murinjapalam|              2|
# |  2024-05-31 02:26:00|East Fort North B...|              7|
# |  2024-05-31 02:26:00|Thampanoor Railwa...|              3|
# |  2024-05-31 02:26:00|Thampanoor Main B...|              6|
# |  2024-05-31 02:26:00|             Kowdiar|              1|
# |  2024-05-31 02:26:00|    Peroorkada Depot|              5|
# |  2024-05-31 02:27:00|East Fort South B...|              1|
# |  2024-05-31 02:27:00|         Statue Bsnl|              1|
# |  2024-05-31 02:27:00|East Fort North B...|              6|
# |  2024-05-31 02:27:00|Thampanoor Main B...|              2|
# |  2024-05-31 02:27:00|   Pettah Pallimukku|              1|
# |  2024-05-31 02:27:00|Thampanoor Railwa...|              3|
# |  2024-05-31 02:27:00|    Peroorkada Depot|             13|
# |  2024-05-31 02:27:00|Medical College T...|              2|
# |  2024-05-31 02:28:00|Lms Corporation O...|              3|
# |  2024-05-31 02:28:00|East Fort North B...|              5|
# |  2024-05-31 02:28:00|East Fort South B...|              1|
# |  2024-05-31 02:28:00|         Statue Bsnl|              2|
# |  2024-05-31 02:28:00|    Peroorkada Depot|             10|
# |  2024-05-31 02:28:00|   Pettah Pallimukku|              2|
# |  2024-05-31 02:28:00|   Pattom Sut Office|              1|
# |  2024-05-31 02:28:00|Medical College T...|              1|
# |  2024-05-31 02:28:00|             Kowdiar|              1|
# |  2024-05-31 02:29:00|    Peroorkada Depot|             14|
# |  2024-05-31 02:29:00|East Fort North B...|              2|
# |  2024-05-31 02:29:00|East Fort South B...|              2|
# |  2024-05-31 02:40:00|Law College Junct...|              1|
# |  2024-05-31 02:40:00|East Fort South B...|              5|
# |  2024-05-31 02:40:00|Medical College T...|              2|
# |  2024-05-31 02:40:00|    Peroorkada Depot|             12|
# |  2024-05-31 02:40:00|Thampanoor Main B...|              1|
# |  2024-05-31 02:41:00|Medical College T...|              4|
# |  2024-05-31 02:41:00|    Peroorkada Depot|              5|
# |  2024-05-31 02:41:00|Lms Corporation O...|              1|
# |  2024-05-31 02:41:00|       Fort Hospital|              2|
# |  2024-05-31 02:42:00|    Peroorkada Depot|              2|
# |  2024-05-31 02:42:00|       Fort Hospital|              1|
# |  2024-05-31 02:43:00|         Statue Bsnl|              1|
# |  2024-05-31 02:43:00|             Kowdiar|              1|
# |  2024-05-31 02:43:00|    Peroorkada Depot|              1|
# |  2024-05-31 02:44:00|Pettah Pallimukku...|              1|
# |  2024-05-31 02:44:00|    Peroorkada Depot|              1|
# |  2024-05-31 02:44:00|Law College Junct...|              3|
# |  2024-05-31 02:45:00|Pettah Pallimukku...|              4|
# |  2024-05-31 02:45:00|                 Pmg|              3|
# |  2024-05-31 02:45:00|    Peroorkada Depot|              3|
# |  2024-05-31 02:45:00|Law College Junct...|              2|
# |  2024-05-31 02:45:00|         Statue Bsnl|              2|
# |  2024-05-31 02:45:00|             Kowdiar|              1|
# |  2024-05-31 02:46:00|    Peroorkada Depot|              8|
# |  2024-05-31 02:46:00|                 Pmg|              3|
# |  2024-05-31 02:46:00|Statue Sbi Or Sec...|              4|
# |  2024-05-31 02:46:00|Law College Junct...|              1|
# |  2024-05-31 02:47:00|                 Pmg|              4|
# |  2024-05-31 02:47:00|             Kowdiar|              3|
# |  2024-05-31 02:47:00|    Peroorkada Depot|             11|
# |  2024-05-31 02:47:00|        Murinjapalam|              1|
# |  2024-05-31 02:47:00|Pettah Pallimukku...|              1|
# |  2024-05-31 02:48:00|   Pattom Sut Office|              3|
# |  2024-05-31 02:48:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 02:48:00|    Peroorkada Depot|              8|
# |  2024-05-31 02:48:00|         Statue Bsnl|              1|
# |  2024-05-31 02:48:00|East Fort South B...|              1|
# |  2024-05-31 02:48:00|Medical College T...|              7|
# |  2024-05-31 02:49:00|    Peroorkada Depot|             12|
# |  2024-05-31 02:49:00|East Fort South B...|              7|
# |  2024-05-31 02:49:00|Medical College T...|              4|
# |  2024-05-31 02:49:00|Thampanoor Main B...|              2|
# |  2024-05-31 03:00:00|       Fort Hospital|              1|
# |  2024-05-31 03:00:00|           Mettukada|              4|
# |  2024-05-31 03:00:00|             Kowdiar|              2|
# |  2024-05-31 03:00:00|East Fort South B...|              4|
# |  2024-05-31 03:00:00|     Kesavadasapuram|              2|
# |  2024-05-31 03:00:00|Thampanoor Main B...|              5|
# |  2024-05-31 03:00:00|    Peroorkada Depot|              3|
# |  2024-05-31 03:00:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 03:00:00|         Statue Bsnl|              2|
# |  2024-05-31 03:01:00|       Vellayambalam|              3|
# |  2024-05-31 03:01:00|           Mettukada|              5|
# |  2024-05-31 03:01:00|         Ambalamukku|              2|
# |  2024-05-31 03:01:00|East Fort South B...|              2|
# |  2024-05-31 03:02:00|           Mettukada|              1|
# |  2024-05-31 03:02:00|       Vellayambalam|              1|
# |  2024-05-31 03:02:00|Law College Junct...|              1|
# |  2024-05-31 03:02:00|         Ambalamukku|              1|
# |  2024-05-31 03:02:00|East Fort South B...|              8|
# |  2024-05-31 03:02:00|     Kesavadasapuram|              2|
# |  2024-05-31 03:02:00|Thampanoor Main B...|              1|
# |  2024-05-31 03:03:00|             Kowdiar|              1|
# |  2024-05-31 03:03:00|                 Pmg|              1|
# |  2024-05-31 03:03:00|         Ambalamukku|              1|
# |  2024-05-31 03:03:00|    Peroorkada Depot|             12|
# |  2024-05-31 03:03:00|East Fort South B...|              1|
# |  2024-05-31 03:03:00|     Kesavadasapuram|              5|
# |  2024-05-31 03:04:00|                 Pmg|              5|
# |  2024-05-31 03:04:00|         Statue Bsnl|              1|
# |  2024-05-31 03:04:00|Pettah Pallimukku...|              2|
# |  2024-05-31 03:04:00|    Peroorkada Depot|              9|
# |  2024-05-31 03:04:00|       Vellayambalam|              2|
# |  2024-05-31 03:04:00|         Ambalamukku|              3|
# |  2024-05-31 03:04:00|   Pattom Sut Office|              2|
# |  2024-05-31 03:04:00|     Kesavadasapuram|              3|
# |  2024-05-31 03:04:00|Law College Junct...|              1|
# |  2024-05-31 03:05:00|                 Pmg|              6|
# |  2024-05-31 03:05:00|    Peroorkada Depot|              4|
# |  2024-05-31 03:05:00|             Kowdiar|              2|
# |  2024-05-31 03:05:00|Pettah Pallimukku...|              9|
# |  2024-05-31 03:05:00|         Statue Bsnl|              1|
# |  2024-05-31 03:05:00|         Ambalamukku|              3|
# |  2024-05-31 03:06:00|             Kowdiar|              2|
# |  2024-05-31 03:06:00|Law College Junct...|              1|
# |  2024-05-31 03:06:00|    Peroorkada Depot|              5|
# |  2024-05-31 03:06:00|Thampanoor Main B...|              4|
# |  2024-05-31 03:06:00|       Vellayambalam|              1|
# |  2024-05-31 03:06:00|Pettah Pallimukku...|              8|
# |  2024-05-31 03:07:00|East Fort South B...|              3|
# |  2024-05-31 03:07:00|                 Pmg|              2|
# |  2024-05-31 03:07:00|Pettah Pallimukku...|              3|
# |  2024-05-31 03:07:00|Thampanoor Main B...|              2|
# |  2024-05-31 03:07:00|Law College Junct...|              1|
# |  2024-05-31 03:07:00|             Kowdiar|              3|
# |  2024-05-31 03:07:00|    Peroorkada Depot|              4|
# |  2024-05-31 03:08:00|Law College Junct...|              1|
# |  2024-05-31 03:08:00|     Kesavadasapuram|              1|
# |  2024-05-31 03:08:00|    Peroorkada Depot|              4|
# |  2024-05-31 03:08:00|                 Pmg|              2|
# |  2024-05-31 03:08:00|         Statue Bsnl|              1|
# |  2024-05-31 03:08:00|         Ambalamukku|              1|
# |  2024-05-31 03:08:00|Pettah Pallimukku...|              1|
# |  2024-05-31 03:08:00|East Fort South B...|              3|
# |  2024-05-31 03:09:00|Vazhuthacaud Wome...|              1|
# |  2024-05-31 03:09:00|Lms Corporation O...|              3|
# |  2024-05-31 03:09:00|    Peroorkada Depot|              5|
# |  2024-05-31 03:09:00|         Statue Bsnl|              4|
# |  2024-05-31 03:09:00|East Fort South B...|              1|
# |  2024-05-31 03:09:00|     Kesavadasapuram|              1|
# |  2024-05-31 03:09:00|              Museum|              1|
# |  2024-05-31 03:20:00|         Statue Bsnl|              2|
# |  2024-05-31 03:20:00|East Fort North B...|              4|
# |  2024-05-31 03:20:00|    Peroorkada Depot|              2|
# |  2024-05-31 03:20:00|         Kumarapuram|              2|
# |  2024-05-31 03:20:00|        Murinjapalam|              1|
# |  2024-05-31 03:21:00|East Fort North B...|              7|
# |  2024-05-31 03:21:00|Lms Corporation O...|              1|
# |  2024-05-31 03:21:00|    Peroorkada Depot|              2|
# |  2024-05-31 03:21:00|         Statue Bsnl|              2|
# |  2024-05-31 03:21:00|     Kesavadasapuram|              2|
# |  2024-05-31 03:21:00|           Mettukada|              2|
# |  2024-05-31 03:22:00|    Peroorkada Depot|              1|
# |  2024-05-31 03:22:00|     Kesavadasapuram|              1|
# |  2024-05-31 03:22:00|         Statue Bsnl|              1|
# |  2024-05-31 03:22:00|East Fort North B...|              4|
# |  2024-05-31 03:23:00|         Kumarapuram|              1|
# |  2024-05-31 03:23:00|East Fort North B...|              4|
# |  2024-05-31 03:23:00|        Murinjapalam|              1|
# |  2024-05-31 03:23:00|East Fort South B...|              5|
# |  2024-05-31 03:24:00|    Peroorkada Depot|              1|
# |  2024-05-31 03:24:00|        Paippinmoodu|              3|
# |  2024-05-31 03:24:00|East Fort South B...|             11|
# |  2024-05-31 03:24:00|        Murinjapalam|              6|
# |  2024-05-31 03:24:00|   Pattom Sut Office|              3|
# |  2024-05-31 03:24:00|         Kumarapuram|              2|
# |  2024-05-31 03:24:00|Museum Public Off...|              1|
# |  2024-05-31 03:24:00|       Vellayambalam|              2|
# |  2024-05-31 03:24:00|Palayam Fine Arts...|              1|
# |  2024-05-31 03:25:00|East Fort South B...|              9|
# |  2024-05-31 03:25:00|   Pattom Sut Office|              2|
# |  2024-05-31 03:25:00|Thampanoor Railwa...|              4|
# |  2024-05-31 03:25:00|Medical College T...|              1|
# |  2024-05-31 03:25:00|        Paippinmoodu|              1|
# |  2024-05-31 03:25:00|       Vellayambalam|              4|
# |  2024-05-31 03:26:00|East Fort South B...|              8|
# |  2024-05-31 03:26:00|Medical College T...|              3|
# |  2024-05-31 03:26:00|Thampanoor Main B...|              5|
# |  2024-05-31 03:26:00|Thampanoor Railwa...|              2|
# |  2024-05-31 03:26:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:26:00|    Peroorkada Depot|              5|
# |  2024-05-31 03:26:00|        Murinjapalam|              6|
# |  2024-05-31 03:27:00|         Kumarapuram|              3|
# |  2024-05-31 03:27:00|Thampanoor Main B...|              5|
# |  2024-05-31 03:27:00|        Murinjapalam|              2|
# |  2024-05-31 03:27:00|East Fort South B...|              3|
# |  2024-05-31 03:27:00|Medical College T...|              1|
# |  2024-05-31 03:27:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:27:00|    Peroorkada Depot|              5|
# |  2024-05-31 03:28:00|         Kumarapuram|              2|
# |  2024-05-31 03:28:00|Medical College T...|              3|
# |  2024-05-31 03:28:00|        Paippinmoodu|              1|
# |  2024-05-31 03:28:00|East Fort South B...|              8|
# |  2024-05-31 03:28:00|   Pattom Sut Office|              2|
# |  2024-05-31 03:28:00|    Peroorkada Depot|              6|
# |  2024-05-31 03:28:00|East Fort North B...|              6|
# |  2024-05-31 03:28:00|Palayam Fine Arts...|              2|
# |  2024-05-31 03:28:00|Thampanoor Main B...|              7|
# |  2024-05-31 03:29:00|East Fort South B...|              1|
# |  2024-05-31 03:29:00|East Fort North B...|              8|
# |  2024-05-31 03:29:00|    Peroorkada Depot|              7|
# |  2024-05-31 03:29:00|Palayam Fine Arts...|              4|
# |  2024-05-31 03:29:00|     Bakery Junction|              1|
# |  2024-05-31 03:29:00|Thampanoor Main B...|              4|
# |  2024-05-31 03:29:00|         Kumarapuram|              8|
# |  2024-05-31 03:40:00|Thampanoor Main B...|              5|
# |  2024-05-31 03:40:00|             Kowdiar|              1|
# |  2024-05-31 03:40:00|Medical College T...|              1|
# |  2024-05-31 03:40:00|Statue Sbi Or Sec...|              1|
# |  2024-05-31 03:40:00|Easwara Vilasam C...|              1|
# |  2024-05-31 03:40:00|Palayam Fine Arts...|              6|
# |  2024-05-31 03:40:00|East Fort South B...|              1|
# |  2024-05-31 03:40:00|         Statue Bsnl|              2|
# |  2024-05-31 03:40:00|East Fort North B...|              4|
# |  2024-05-31 03:40:00|         Kumarapuram|              7|
# |  2024-05-31 03:40:00|    Peroorkada Depot|              7|
# |  2024-05-31 03:41:00|        Murinjapalam|              1|
# |  2024-05-31 03:41:00|East Fort South B...|              3|
# |  2024-05-31 03:41:00|Thampanoor Main B...|              7|
# |  2024-05-31 03:41:00|Medical College T...|              1|
# |  2024-05-31 03:41:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:41:00|East Fort North B...|              3|
# |  2024-05-31 03:41:00|Palayam Fine Arts...|              4|
# |  2024-05-31 03:42:00|East Fort North B...|             13|
# |  2024-05-31 03:42:00|Thampanoor Main B...|              6|
# |  2024-05-31 03:42:00|    Peroorkada Depot|              4|
# |  2024-05-31 03:42:00|Medical College T...|              1|
# |  2024-05-31 03:42:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 03:42:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:42:00|East Fort South B...|              7|
# |  2024-05-31 03:43:00|Statue Sbi Or Sec...|              4|
# |  2024-05-31 03:43:00|East Fort North B...|             10|
# |  2024-05-31 03:43:00|Thampanoor Main B...|              6|
# |  2024-05-31 03:43:00|         Kumarapuram|              3|
# |  2024-05-31 03:43:00|East Fort South B...|              4|
# |  2024-05-31 03:43:00|    Peroorkada Depot|             13|
# |  2024-05-31 03:44:00|         Kumarapuram|              4|
# |  2024-05-31 03:44:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:44:00|    Peroorkada Depot|             12|
# |  2024-05-31 03:44:00|East Fort North B...|              8|
# |  2024-05-31 03:44:00|East Fort South B...|              5|
# |  2024-05-31 03:44:00|        Murinjapalam|              2|
# |  2024-05-31 03:44:00|Thampanoor Railwa...|              8|
# |  2024-05-31 03:44:00|Thampanoor Main B...|              1|
# |  2024-05-31 03:45:00|East Fort South B...|              5|
# |  2024-05-31 03:45:00|             Kowdiar|              4|
# |  2024-05-31 03:45:00|East Fort North B...|              6|
# |  2024-05-31 03:45:00|Thampanoor Railwa...|              4|
# |  2024-05-31 03:45:00|    Peroorkada Depot|             13|
# |  2024-05-31 03:45:00|Thampanoor Main B...|              1|
# |  2024-05-31 03:45:00|Statue Sbi Or Sec...|              1|
# |  2024-05-31 03:46:00|           Mettukada|              1|
# |  2024-05-31 03:46:00|Thampanoor Railwa...|              5|
# |  2024-05-31 03:46:00|    Peroorkada Depot|              8|
# |  2024-05-31 03:46:00|             Kowdiar|              1|
# |  2024-05-31 03:46:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 03:46:00|        Murinjapalam|              2|
# |  2024-05-31 03:46:00|East Fort South B...|              6|
# |  2024-05-31 03:46:00|East Fort North B...|              5|
# |  2024-05-31 03:47:00|Thampanoor Railwa...|              7|
# |  2024-05-31 03:47:00|        Murinjapalam|              1|
# |  2024-05-31 03:47:00|    Peroorkada Depot|              9|
# |  2024-05-31 03:47:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 03:47:00|   Pettah Pallimukku|              1|
# |  2024-05-31 03:47:00|East Fort South B...|              3|
# |  2024-05-31 03:48:00|Thampanoor Main B...|              1|
# |  2024-05-31 03:48:00|Thampanoor Railwa...|              3|
# |  2024-05-31 03:48:00|           Mettukada|              2|
# |  2024-05-31 03:48:00|       Fort Hospital|              1|
# |  2024-05-31 03:48:00|Statue Sbi Or Sec...|              1|
# |  2024-05-31 03:48:00|       Vellayambalam|              2|
# |  2024-05-31 03:48:00|        Murinjapalam|              2|
# |  2024-05-31 03:48:00|    Peroorkada Depot|              8|
# |  2024-05-31 03:49:00|Thampanoor Main B...|              3|
# |  2024-05-31 03:49:00|    Peroorkada Depot|              2|
# |  2024-05-31 03:49:00|           Mettukada|              4|
# |  2024-05-31 03:49:00|   Pattom Sut Office|              1|
# |  2024-05-31 03:49:00|Thampanoor Railwa...|              1|
# |  2024-05-31 03:49:00|       Vellayambalam|              3|
# |  2024-05-31 04:00:00|Medical College T...|              2|
# |  2024-05-31 04:00:00|             Kowdiar|              1|
# |  2024-05-31 04:00:00|East Fort North B...|              2|
# |  2024-05-31 04:00:00|Kunnumpuram Junction|              1|
# |  2024-05-31 04:00:00|Edapazhanji Pango...|              1|
# |  2024-05-31 04:00:00|   Pettah Pallimukku|              1|
# |  2024-05-31 04:00:00|East Fort South B...|              5|
# |  2024-05-31 04:00:00|Thampanoor Main B...|              2|
# |  2024-05-31 04:00:00|Thampanoor Railwa...|              3|
# |  2024-05-31 04:01:00|Medical College T...|              2|
# |  2024-05-31 04:01:00|             Kowdiar|              1|
# |  2024-05-31 04:01:00|Thampanoor Railwa...|             10|
# |  2024-05-31 04:01:00|East Fort South B...|             10|
# |  2024-05-31 04:01:00|East Fort North B...|              7|
# |  2024-05-31 04:02:00|Medical College T...|              1|
# |  2024-05-31 04:02:00|East Fort South B...|             14|
# |  2024-05-31 04:02:00|East Fort North B...|              4|
# |  2024-05-31 04:02:00|    Peroorkada Depot|              1|
# |  2024-05-31 04:02:00|Thampanoor Railwa...|             11|
# |  2024-05-31 04:02:00|             Kowdiar|              1|
# |  2024-05-31 04:02:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 04:03:00|         Statue Bsnl|              1|
# |  2024-05-31 04:03:00|    Peroorkada Depot|              7|
# |  2024-05-31 04:03:00|East Fort North B...|              8|
# |  2024-05-31 04:03:00|Medical College T...|              2|
# |  2024-05-31 04:03:00|East Fort South B...|             15|
# |  2024-05-31 04:03:00|Thampanoor Railwa...|              7|
# |  2024-05-31 04:04:00|Medical College T...|              3|
# |  2024-05-31 04:04:00|             Kowdiar|              2|
# |  2024-05-31 04:04:00|East Fort North B...|              6|
# |  2024-05-31 04:04:00|East Fort South B...|             11|
# |  2024-05-31 04:04:00|    Peroorkada Depot|              7|
# |  2024-05-31 04:04:00|Thampanoor Railwa...|              7|
# |  2024-05-31 04:04:00|         Statue Bsnl|              2|
# |  2024-05-31 04:05:00|    Peroorkada Depot|              5|
# |  2024-05-31 04:05:00|Thampanoor Railwa...|              5|
# |  2024-05-31 04:05:00|East Fort South B...|             14|
# |  2024-05-31 04:05:00|             Pattoor|              3|
# |  2024-05-31 04:05:00|           Mettukada|              1|
# |  2024-05-31 04:05:00|Medical College T...|              3|
# |  2024-05-31 04:06:00|East Fort South B...|              5|
# |  2024-05-31 04:06:00|East Fort North B...|              4|
# |  2024-05-31 04:06:00|Statue Sbi Or Sec...|              1|
# |  2024-05-31 04:06:00|Thampanoor Railwa...|              7|
# |  2024-05-31 04:06:00|             Pattoor|              4|
# |  2024-05-31 04:06:00|    Peroorkada Depot|             15|
# |  2024-05-31 04:07:00|Thampanoor Railwa...|              4|
# |  2024-05-31 04:07:00|Lms Corporation O...|              1|
# |  2024-05-31 04:07:00|    Peroorkada Depot|             11|
# |  2024-05-31 04:07:00|East Fort South B...|              2|
# |  2024-05-31 04:07:00|         Statue Bsnl|              1|
# |  2024-05-31 04:08:00|Lms Corporation O...|              1|
# |  2024-05-31 04:08:00|East Fort South B...|              1|
# |  2024-05-31 04:08:00|             Pattoor|              1|
# |  2024-05-31 04:08:00|       Vellayambalam|              2|
# |  2024-05-31 04:08:00|Medical College T...|              2|
# |  2024-05-31 04:08:00|    Peroorkada Depot|             15|
# |  2024-05-31 04:09:00|   Kerala University|              1|
# |  2024-05-31 04:09:00|         Ambalamukku|              2|
# |  2024-05-31 04:09:00|    Peroorkada Depot|              9|
# |  2024-05-31 04:20:00|East Fort South B...|              2|
# |  2024-05-31 04:20:00|         Ambalamukku|              1|
# |  2024-05-31 04:20:00|    Peroorkada Depot|             10|
# |  2024-05-31 04:20:00|Thampanoor Railwa...|              2|
# |  2024-05-31 04:20:00|         Statue Bsnl|              1|
# |  2024-05-31 04:21:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 04:21:00|             Kowdiar|              1|
# |  2024-05-31 04:21:00|    Peroorkada Depot|             15|
# |  2024-05-31 04:21:00|   Kerala University|              4|
# |  2024-05-31 04:21:00|       Fort Hospital|              2|
# |  2024-05-31 04:21:00|Palayam Fine Arts...|              1|
# |  2024-05-31 04:21:00|   Pattom Sut Office|              1|
# |  2024-05-31 04:21:00|East Fort South B...|              1|
# |  2024-05-31 04:22:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 04:22:00|    Peroorkada Depot|             11|
# |  2024-05-31 04:22:00|East Fort South B...|              1|
# |  2024-05-31 04:22:00|                 Pmg|              1|
# |  2024-05-31 04:22:00|           Mettukada|              6|
# |  2024-05-31 04:22:00|             Kowdiar|              2|
# |  2024-05-31 04:22:00|         Ambalamukku|              1|
# |  2024-05-31 04:22:00|         Statue Bsnl|              5|
# |  2024-05-31 04:22:00|   Kerala University|              6|
# |  2024-05-31 04:22:00|Palayam Fine Arts...|              2|
# |  2024-05-31 04:23:00|Palayam Fine Arts...|              6|
# |  2024-05-31 04:23:00|East Fort South B...|              4|
# |  2024-05-31 04:23:00|       Vellayambalam|              2|
# |  2024-05-31 04:23:00|   Pattom Sut Office|              5|
# |  2024-05-31 04:23:00|   Kerala University|              2|
# |  2024-05-31 04:23:00|    Peroorkada Depot|              2|
# |  2024-05-31 04:23:00|         Statue Bsnl|              4|
# |  2024-05-31 04:23:00|         Ambalamukku|              3|
# |  2024-05-31 04:23:00|           Mettukada|              5|
# |  2024-05-31 04:24:00|    Peroorkada Depot|              2|
# |  2024-05-31 04:24:00|Medical College T...|              3|
# |  2024-05-31 04:24:00|   Pattom Sut Office|              5|
# |  2024-05-31 04:24:00|Statue Sbi Or Sec...|              2|
# |  2024-05-31 04:24:00|           Mettukada|              6|
# |  2024-05-31 04:24:00|Pettah Pallimukku...|              2|
# |  2024-05-31 04:24:00|       Vellayambalam|              2|
# |  2024-05-31 04:24:00|East Fort South B...|              5|
# |  2024-05-31 04:24:00|         Ambalamukku|              5|
# |  2024-05-31 04:24:00|         Statue Bsnl|              4|
# |  2024-05-31 04:24:00|   Kerala University|              1|
# |  2024-05-31 04:25:00|Vellayambalam Ela...|              1|
# |  2024-05-31 04:25:00|       Vellayambalam|              2|
# |  2024-05-31 04:25:00|Pettah Pallimukku...|              7|
# |  2024-05-31 04:25:00|         Ambalamukku|              3|
# |  2024-05-31 04:25:00|           Mettukada|              4|
# |  2024-05-31 04:25:00|Thampanoor Main B...|              1|
# |  2024-05-31 04:25:00|   Pattom Sut Office|              3|
# |  2024-05-31 04:25:00|East Fort South B...|              5|
# |  2024-05-31 04:25:00|    Peroorkada Depot|              7|
# |  2024-05-31 04:25:00|        Paippinmoodu|              3|
# |  2024-05-31 04:25:00|Medical College T...|              2|
# |  2024-05-31 04:26:00|Pettah Pallimukku...|              1|
# |  2024-05-31 04:26:00|Medical College T...|              1|
# |  2024-05-31 04:26:00|        Paippinmoodu|              2|
# |  2024-05-31 04:26:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 04:26:00|East Fort South B...|              4|
# |  2024-05-31 04:26:00|       Vellayambalam|              3|
# |  2024-05-31 04:26:00|   Pattom Sut Office|              4|
# |  2024-05-31 04:26:00|    Peroorkada Depot|              3|
# |  2024-05-31 04:26:00|Thampanoor Main B...|              7|
# |  2024-05-31 04:26:00|           Mettukada|              3|
# |  2024-05-31 04:27:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 04:27:00|     Kesavadasapuram|              1|
# |  2024-05-31 04:27:00|   Pattom Sut Office|              2|
# |  2024-05-31 04:27:00|Thampanoor Main B...|              8|
# |  2024-05-31 04:27:00|    Peroorkada Depot|              3|
# |  2024-05-31 04:27:00|East Fort South B...|              7|
# |  2024-05-31 04:27:00|        Paippinmoodu|              4|
# |  2024-05-31 04:27:00|         Ambalamukku|              4|
# |  2024-05-31 04:27:00|       Vellayambalam|              3|
# |  2024-05-31 04:27:00|           Mettukada|              4|
# |  2024-05-31 04:28:00|           Mettukada|              5|
# |  2024-05-31 04:28:00|   Pattom Sut Office|              3|
# |  2024-05-31 04:28:00|     Kesavadasapuram|              1|
# |  2024-05-31 04:28:00|Thampanoor Main B...|              2|
# |  2024-05-31 04:28:00|        Paippinmoodu|              4|
# |  2024-05-31 04:28:00|Statue Sbi Or Sec...|              4|
# |  2024-05-31 04:28:00|East Fort South B...|              4|
# |  2024-05-31 04:28:00|Vellayambalam Ela...|              1|
# |  2024-05-31 04:29:00|     Kesavadasapuram|              2|
# |  2024-05-31 04:29:00|           Mettukada|              2|
# |  2024-05-31 04:29:00|    Peroorkada Depot|              5|
# |  2024-05-31 04:29:00|        Paippinmoodu|              3|
# |  2024-05-31 04:29:00|                 Pmg|              1|
# |  2024-05-31 04:29:00|Statue Sbi Or Sec...|              3|
# |  2024-05-31 04:29:00|Thampanoor Main B...|              1|
# |  2024-05-31 04:29:00|East Fort South B...|              3|
# |  2024-05-31 04:29:00|   Pattom Sut Office|              4|
# |  2024-05-31 04:29:00|             Kowdiar|              1|
# |  2024-05-31 04:29:00|       Vellayambalam|              3|
# |  2024-05-31 04:40:00|         Kumarapuram|              2|
# |  2024-05-31 04:40:00|        Paippinmoodu|              1|
# |  2024-05-31 04:40:00|                 Pmg|              1|
# +---------------------+--------------------+---------------+
# only showing top 500 rows

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col
import matplotlib.pyplot as plt
import numpy as np

# Define the specific time range
start_time = "2024-06-05 06:45:00"
end_time = "2024-06-05 09:45:00"

# Aggregate data to get total passenger count per bus stop within the time range
# Sort by total passengers in descending order and select the top 10
top_bus_stops = (
    aggregated_data_from.groupBy("FROM_STOP_NAME")
    .agg(F.sum("TOTAL_PASSENGER").alias("TOTAL_PASSENGER"))
    .orderBy("TOTAL_PASSENGER", ascending=False)
    .limit(20)
    .collect()
)
selected_stops = [stop["FROM_STOP_NAME"] for stop in top_bus_stops]

# Filter data for only the selected bus stops and within the specific time range
filtered_data = aggregated_data_from.filter(
    (col("FROM_STOP_NAME").isin(selected_stops)) &
    (col("TICKET_DATETIME_10MIN") >= start_time) &
    (col("TICKET_DATETIME_10MIN") <= end_time)
)

# Aggregate data to sum up passengers at each stop within the time range
aggregated_stop_data = (
    filtered_data.groupBy("FROM_STOP_NAME")
    .agg(F.sum("TOTAL_PASSENGER").alias("TOTAL_PASSENGER"))
    .collect()
)

# Map bus stops to passenger counts
stop_passenger_data = {row["FROM_STOP_NAME"]: row["TOTAL_PASSENGER"] for row in aggregated_stop_data}

# Plot setup with improved spacing
fig, ax = plt.subplots(figsize=(12, 8))

# Define positions for each bus stop on the x-axis and adjust for better spacing
x_positions = np.arange(len(selected_stops))  # Equally space each stop
stop_positions = dict(zip(selected_stops, x_positions))

# Scatter dots vertically around each bus stop based on passenger count
for stop, x_pos in stop_positions.items():
    # Generate random points around each bus stop
    num_passengers = stop_passenger_data.get(stop, 0)
    x_points = np.random.normal(loc=x_pos, scale=0.2, size=num_passengers)  # Narrower spread
    y_points = np.random.normal(loc=0, scale=0.5, size=num_passengers)  # More spread on y-axis for clarity

    # Plot each bus stop as a cluster of dots
    ax.scatter(x_points, y_points, alpha=0.6, s=8, label=stop)

# Update the x-axis tick positions and labels
ax.set_xticks(x_positions)
ax.set_xticklabels(selected_stops, rotation=45, ha="right")

# Remove y-axis ticks since we are only interested in density (not actual values on y-axis)
ax.set_yticks([])

# Add a title and adjust the y-axis range to spread clusters more evenly
ax.set_title("Passenger Density around Selected Bus Stops (Random 10) in Specified Time Range")
ax.set_ylim(-5, 5)

# Place the legend below the plot to avoid overlap with data points
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=3, title="Bus Stops", markerscale=2)

plt.tight_layout()
plt.show()

# %%
# !pip install seaborn
# !pip install py4j
# !pip install dash plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dash in /home/jeev/.local/lib/python3.10/site-packages (2.18.2)
# Requirement already satisfied: plotly in /home/jeev/.local/lib/python3.10/site-packages (5.24.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (3.0.0)
# Requirement already satisfied: Werkzeug<3.1 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (3.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /home/jeev/.local/lib/python3.10/site-packages (from dash) (6.11.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/jeev/.local/lib/python3.10/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /home/jeev/.local/lib/python3.10/site-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in /home/jeev/.local/lib/python3.10/site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /home/jeev/.local/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from dash) (59.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jeev/.local/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /home/jeev/.local/lib/python3.10/site-packages (from plotly) (23.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/jeev/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/jeev/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /home/jeev/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/jeev/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (1.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/jeev/.local/lib/python3.10/site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /home/jeev/.local/lib/python3.10/site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jeev/.local/lib/python3.10/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jeev/.local/lib/python3.10/site-packages (from requests->dash) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jeev/.local/lib/python3.10/site-packages (from requests->dash) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jeev/.local/lib/python3.10/site-packages (from requests->dash) (2023.11.17)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->dash) (1.16.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '1.1build1'

# %%
# !pip install dash plotly
from dash import Dash, dcc, html
import plotly.express as px
import pandas as pd
from pyspark.sql import functions as F
from pyspark.sql.functions import col

# Define the specific time range
start_time = "2024-06-05 06:45:00"
end_time = "2024-06-05 09:45:00"

# Aggregate data to get total passenger count per bus stop within the time range
# Sort by total passengers in descending order and select the top 20
top_bus_stops = (
    aggregated_data_from.groupBy("FROM_STOP_NAME")
    .agg(F.sum("TOTAL_PASSENGER").alias("TOTAL_PASSENGER"))
    .orderBy("TOTAL_PASSENGER", ascending=False)
    .limit(20)
    .collect()
)
selected_stops = [stop["FROM_STOP_NAME"] for stop in top_bus_stops]

# Filter data for only the selected bus stops and within the specific time range
filtered_data = aggregated_data_from.filter(
    (col("FROM_STOP_NAME").isin(selected_stops)) &
    (col("TICKET_DATETIME_10MIN") >= start_time) &
    (col("TICKET_DATETIME_10MIN") <= end_time)
)

# Aggregate data to sum up passengers at each stop within the time range
aggregated_stop_data = (
    filtered_data.groupBy("FROM_STOP_NAME")
    .agg(F.sum("TOTAL_PASSENGER").alias("TOTAL_PASSENGER"))
    .collect()
)

# Convert Spark DataFrame to Pandas DataFrame for use in Plotly
data = pd.DataFrame(aggregated_stop_data)

# Prepare data for Plotly scatter plot
scatter_data = {
    "FROM_STOP_NAME": [],
    "x_position": [],
    "y_position": []
}

for row in aggregated_stop_data:
    stop_name = row["FROM_STOP_NAME"]
    total_passenger = row["TOTAL_PASSENGER"]
    x_position = selected_stops.index(stop_name)

    # Generate random scatter points for each passenger count
    x_points = np.random.normal(loc=x_position, scale=0.2, size=total_passenger)
    y_points = np.random.normal(loc=0, scale=0.5, size=total_passenger)

    scatter_data["FROM_STOP_NAME"].extend([stop_name] * total_passenger)
    scatter_data["x_position"].extend(x_points)
    scatter_data["y_position"].extend(y_points)

# Create a Pandas DataFrame from the scatter data
scatter_df = pd.DataFrame(scatter_data)

# Create a Plotly scatter plot
fig = px.scatter(
    scatter_df,
    x="x_position",
    y="y_position",
    color="FROM_STOP_NAME",
    labels={"x_position": "Bus Stops", "y_position": ""},
    title="Passenger Density around Selected Bus Stops in Specified Time Range",
    hover_data=["FROM_STOP_NAME"]
)

# Adjust layout for better readability
fig.update_layout(
    xaxis=dict(
        tickvals=list(range(len(selected_stops))),
        ticktext=selected_stops,
        tickangle=45
    ),
    yaxis=dict(showticklabels=False),
    legend_title="Bus Stops"
)

# Set up Dash application
app = Dash(__name__)
app.layout = html.Div([
    html.H1("Passenger Density Visualization"),
    dcc.Graph(figure=fig)
])

# Run the Dash app
if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# # Downsample or take a subset
# sampled_data = aggregated_data_from.sample(fraction=0.1)  # adjust fraction as needed

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd


# # Convert Spark DataFrame to Pandas DataFrame for easier plotting
# sampled_data_pd  =  sampled_data.toPandas()  # Now it's small enough to fit in memory


# # Set up the plot
# plt.figure(figsize=(14, 8))

# # Plot with seaborn scatterplot to distinguish `FROM_STOP_NAME` by color
# sns.scatterplot(
#     data=sampled_data_pd ,
#     x="TICKET_DATETIME_10MIN",
#     y="TOTAL_PASSENGER",
#     hue="FROM_STOP_NAME",
#     palette="viridis",
#     s=50,  # size of the dots
#     edgecolor="k",  # add edge color for better visibility
#     alpha=0.7       # make dots slightly transparent
# )

# # Set title and labels
# plt.title("Passenger Counts by 10-Minute Intervals and Stop")
# plt.xlabel("Ticket Issue Time (10-Minute Intervals)")
# plt.ylabel("Total Passengers")
# plt.xticks(rotation=45)

# # Optional: add legend
# plt.legend(title="From Stop Name", bbox_to_anchor=(1.05, 1), loc='upper left')

# # Show plot
# plt.tight_layout()
# plt.show()

# %%
# import plotly.express as px
# import pandas as pd

# # Assuming pandas_data has the aggregated data

# # Plot the scatter plot animation
# fig = px.scatter(
#     pandas_data,
#     x="FROM_STOP_NAME",  # or any other column for x-axis
#     y="TO_STOP_NAME",    # or any other column for y-axis
#     size="TOTAL_PASSENGER",  # bubble size represents the number of passengers
#     color="FROM_STOP_NAME",  # color by stop name to create clusters
#     animation_frame="TICKET_DATETIME",  # time-based animation
#     title="KSRTC Passenger Flow Between Stops Over Time",
#     labels={
#         "FROM_STOP_NAME": "From Stop",
#         "TO_STOP_NAME": "To Stop",
#         "TOTAL_PASSENGER": "Total Passengers"
#     },
# )

# # Show the plot
# fig.show()
